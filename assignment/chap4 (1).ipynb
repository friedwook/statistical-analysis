# %% [markdown]
# # 1. 추측통계의 기본

# %% [markdown]
# ## 1.1 모집단과 표본

# %% [markdown]
# ### 1.1.1. 표본의 추출 방법

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_csv("..\\source\\python_stat_sample-master\\data\\ch4_scores400.csv")
scores = np.array(df['score'])
scores[:10]
